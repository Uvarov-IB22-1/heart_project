# %% [markdown]
# # Импорт библиотек

# %% [markdown]
# # Обучение базовых моделей
# Обучаем 3 модели: Logistic Regression (baseline), Random Forest, Gradient Boosting.
# Сравниваем по метрикам: Accuracy, Precision, Recall, F1, ROC-AUC.
